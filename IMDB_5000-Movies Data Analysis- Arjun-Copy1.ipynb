# %%
import pandas as pd

import matplotlib as plt
import numpy as np

# %%
import pandas as pd
from pandas import Series,DataFrame
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

import pandas as pd

import json

import os

from matplotlib.pyplot import *


import json

# %%
# Reading the CSV file. 
movie_df =  pd.read_csv("C:/Users/arjun/Documents/Imdb_Movie-Project/Dataset/movie_metadata.csv")

# %%
movie_df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
# color                        5024 non-null object
# director_name                4939 non-null object
# num_critic_for_reviews       4993 non-null float64
# duration                     5028 non-null float64
# director_facebook_likes      4939 non-null float64
# actor_3_facebook_likes       5020 non-null float64
# actor_2_name                 5030 non-null object
# actor_1_facebook_likes       5036 non-null float64
# gross                        4159 non-null float64
# genres                       5043 non-null object
# actor_1_name                 5036 non-null object
# movie_title                  5043 non-null object
# num_voted_users              5043 non-null int64
# cast_total_facebook_likes    5043 non-null int64
# actor_3_name                 5020 non-null object
# facenumber_in_poster         5030 non-null float64
# ...

# %%
movie_df.columns
# Out:
# Index([u'color', u'director_name', u'num_critic_for_reviews', u'duration',
#        u'director_facebook_likes', u'actor_3_facebook_likes', u'actor_2_name',
#        u'actor_1_facebook_likes', u'gross', u'genres', u'actor_1_name',
#        u'movie_title', u'num_voted_users', u'cast_total_facebook_likes',
#        u'actor_3_name', u'facenumber_in_poster', u'plot_keywords',
#        u'movie_imdb_link', u'num_user_for_reviews', u'language', u'country',
#        u'content_rating', u'budget', u'title_year', u'actor_2_facebook_likes',
#        u'imdb_score', u'aspect_ratio', u'movie_facebook_likes'],
#       dtype='object')

# %%
#Checking Null values

movie_df.isnull().sum().plot(kind = 'bar',figsize = (10,5))

# %%
movie_df.loc[movie_df['director_name'] == 'David F. Sandberg']
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 3700  Color  David F. Sandberg                   159.0      81.0
#
#       director_facebook_likes  actor_3_facebook_likes  actor_2_name  \
# 3700                     26.0                   300.0  Amiah Miller
#
#       actor_1_facebook_likes       gross  genres         ...           \
# 3700                  2000.0  56536016.0  Horror         ...
#
#      num_user_for_reviews language  country  content_rating     budget  \
# 3700                 95.0  English      USA           PG-13  4900000.0
#
#       title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 3700      2016.0                  509.0        6.9          2.35
#
#      movie_facebook_likes
# 3700                    0
#
# [1 rows x 28 columns]

# %%
each year best movies based on higest rated 

best movie higest budget- for each year 

each year - top 5 rated 
to 5 actors, directors 

no, of mvs, ratings, fb likes 

each year mean avg for quality of movies 

which year had best avg ratings .

# %%
# Top 35 for any two arguments along with any df

def top_35(df, col1, col2):
    #Finds top 35 of two columns!
    sortk = df.nlargest(35, col2)[[col1,col2]].reset_index()
    return sortk

# %%
# Dynamic square function

# n = int(input())

def top_n(df, col1, col2, n):
    #Finds top 35 of two columns!
    topn = df.nlargest(n, col2)[[col1,col2]].reset_index(drop= True)
    return topn

# %%
top_n(movie_df, "genres", "imdb_score",5)
# Out:
#         genres  imdb_score
# 0       Comedy         9.5
# 1  Crime|Drama         9.3
# 2  Crime|Drama         9.2
# 3        Drama         9.1
# 4        Drama         9.1

# %%
movie_df['budget'].dtype
# Out:
# dtype('float64')

# %%
tf = top_35(movie_df, "movie_title", "budget")

# %%
def barplt(df, col1, col2,labelx,labely):
    bplot = df.plot(kind='bar',x=col1 ,y=col2, figsize=(18,9), color='red')
    xl =plt.xlabel(labelx)
    yl = plt.ylabel(labely)
    return bplot, xl,yl

# %%
barplt(tf,"movie_title", "budget","movie-title", "Budget")
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x2eaa7f60>,
# ...
#  <matplotlib.text.Text at 0x2d5d41d0>)

# %%
agg_groupby(movie_df,"genres","movie_title","movie_facebook_likes")

# %%
# Function to Groupby by one colomn w.r.t two other colomns. 
def sum_groupby(df, col1, col2, col3):
    #gropping colomns with sum aggregation. 
    grp = df.groupby(col1)[col2,col3 ].agg('sum')
    return grp

# %%
sum_groupby(movie_df,"director_name","budget","gross").nlargest(100,"budget").head(10)
# Out:
#                         budget         gross
# director_name
# Joon-ho Bong      1.225470e+10  6.764441e+06
# Chan-wook Park    4.215000e+09  4.095234e+06
# Katsuhiro Ôtomo   3.227520e+09  8.495500e+05
# Lajos Koltai      2.500000e+09  1.958880e+05
# Hayao Miyazaki    2.477000e+09  3.214032e+07
# Peter Jackson     1.692000e+09  2.592969e+09
# Steven Spielberg  1.662901e+09  4.114233e+09
# Michael Bay       1.587000e+09  2.231243e+09
# Sam Raimi         1.430975e+09  2.049549e+09
# Ridley Scott      1.430000e+09  1.337772e+09

# %%
rp = movie_df.groupby('director_name')['budget' ].agg('sum')
pr = movie_df.groupby('director_name')['gross' ].agg('sum')

kp = pr/rp

# %%
kp.sort_values(ascending = False)[9:10]
# Out:
# director_name
# Norman Ferguson    32.423077
# dtype: float64

# %%
kp.sort_values(ascending = False).head(10)
# Out:
# director_name
# Jonathan Caouette    2715.660550
# Daniel Myrick        2342.168567
# Travis Cluff          227.578190
# William Cottrell       92.462743
# Joe Camp               79.105200
# Jafar Panahi           67.378000
# Shane Carruth          60.680000
# Robert Townsend        52.286170
# John 'Bud' Cardos      34.000000
# Norman Ferguson        32.423077
# dtype: float64

# %%
kp.sort_values(ascending = False).head(5).plot(kind= 'bar')

# %%
total gross/ total budget = return on investment

# %%
f = movie_df['budget'].sum()
g = movie_df['gross'].sum()

k = f/g
k

# %%
# Function to Groupby by one colomn w.r.t two other colomns. 

def mean_groupby(df, col1, col2, col3):
    #gropping colomns with mean aggregation. 
    grp = df.groupby(col1)[col2,col3 ].agg('mean')
    return grp

# %%
mean_groupby(movie_df,"director_name","budget","gross").nlargest(5,"budget").head(5)
# Out:
#                        budget       gross
# director_name
# Joon-ho Bong     6.127350e+09   3382220.5
# Lajos Koltai     2.500000e+09    195888.0
# Katsuhiro Ôtomo  1.613760e+09    424775.0
# Chan-wook Park   1.405000e+09   1365078.0
# Takao Okawara    1.000000e+09  10037390.0

# %%
agg_groupby(movie_df,"budget","movie_title","movie_facebook_likes").plot(kind = 'bar')

# %%
movie_fb_likes = movie_df.groupby('movie_title')['budget', 'movie_facebook_likes'].agg('sum')
movie_fb_likes.head()
# Out:
#                                  budget  movie_facebook_likes
# movie_title
# #Horror                       1500000.0                   750
# 10 Cloverfield Lane          15000000.0                 33000
# 10 Days in a Madhouse        12000000.0                 26000
# 10 Things I Hate About You   16000000.0                 10000
# 10,000 B.C.                         NaN                     0

# %%
# plt.scatter(movie_fb_likes['budget'], movie_fb_likes['movie_facebook_likes'], marker='.')

def splotting(df, col1, col2):
    splt =plt.scatter(movie_fb_likes['budget'], movie_fb_likes['movie_facebook_likes'], marker='.')
    return splt

# %%
def sctrplt(df, col1, col2,labelx, labely):
    # scatter plot for two columns.
    splt =plt.scatter(df[col1], df[col2], marker='.')
    xl =plt.xlabel(labelx)
    yl = plt.ylabel(labely)
    return splt, xl,yl

# %%
# Function to plot a Scatter plot with two variablels in a given Dataframe(df).

def sctrplt(df, col1, col2):
    # scatter plot for two columns.
    splt =plt.scatter(df[col1], df[col2], marker='.')
    return splt

# %%
sctrplt(movie_df, "imdb_score", "movie_facebook_likes", "imdb", "fb")
# Out:
# (<matplotlib.collections.PathCollection at 0x149fcf60>,
# ...
#  <matplotlib.text.Text at 0x133fe438>)

# %%
y = list([x for x in movie_df['imdb_score'] if x >= 9])

y
# Out:
# [9.0,
#  9.3000000000000007,
#  9.5,
#  9.0999999999999996,
#  9.0,
#  9.0999999999999996,
#  9.1999999999999993,
#  9.0,
#  9.0999999999999996]

# %%
 def tyr(df,col1,col2,year,n):
        myr = df.nlargest(n, col2)[col1].loc[year]
        myr = myr.sort_values(ascending = False)
        return myr

# %%
 def tyyy(df,col1,col2,year):
        myr = df.groupby([col1,col2]).max().loc[year]
#         myr = myr.max()
#         myr = myr.sort_values(ascending = False)
        return myr

# %%
tyyy(movie_df, "title_year", "imdb_score", 2005)
# Out:
#                        color       director_name  num_critic_for_reviews  \
# imdb_score
# 1.9                    Color       A. Raven Cruz                     3.0
# 2.2                    Color   Lawrence Guterman                    78.0
# 2.3                    Color            Uwe Boll                   148.0
# 2.9                    Color            Uwe Boll                   143.0
# 3.3                    Color  Philip Zlotorynski                    14.0
# 3.5                    Color    Robert Rodriguez                    66.0
# 4.0                    Color         Steve Boyum                    41.0
# 4.1                    Color         Stephen Kay                   140.0
# 4.2                    Color         Peter Hyams                   113.0
# 4.3                    Color          Mark Brown                    77.0
# 4.6                    Color        Mike Bigelow                    98.0
# 4.7                    Color     Angela Robinson                   117.0
# ...

# %%
number = int(input())

def square(x):
    return x ** 2

print (square(number))
# Out:
# 2
# 4

# %%
#Function to Print Top 10 of any two columns from a Dtaframe(df), and resets the index.
# df = str(input())
# col1 = str(input())
# col2 = str(input())
def tp_10(df, col1, col2):
    #to find Top 10 of any two columns(col1, col2), in a Dataframe(df).
    t10 = df.nlargest(10, col2)[[str(input()),col2]].reset_index(drop=True)
    return t10

# %%
#Function to Print Top 10 of any two columns from a Dtaframe(df), and resets the index.
def top_10(df, col1, col2):
    #to find Top 10 of any two columns(col1, col2), in a Dataframe(df).
    t10 = df.nlargest(10, col2)[[col1,col2]].reset_index(drop=True)
    return t10

# %%
def top_10(df, col1, col2):
    #to find Top 10 of any two columns(col1, col2), in a Dataframe(df).
    t10 = df.nlargest(10, col2)[[col1,col2]].reset_index(drop=True)
    return t10

# %%
top_10(movie_df,"genres", "imdb_score")
# Out:
#                            genres  imdb_score
# 0                          Comedy         9.5
# 1                     Crime|Drama         9.3
# 2                     Crime|Drama         9.2
# 3                           Drama         9.1
# 4                           Drama         9.1
# 5                          Action         9.1
# 6     Action|Crime|Drama|Thriller         9.0
# 7                     Crime|Drama         9.0
# 8            Crime|Drama|Thriller         9.0
# 9  Action|Adventure|Drama|Fantasy         8.9

# %%
# Function to find Top 25 movies using 2 columns!

def top_25(df, col1, col2):
    t25 = df.nlargest(25, col2)[[col1,col2]].reset_index(drop=True)
    return t25

# %%
top_25(movie_df,"actor_1_name", "imdb_score")
# Out:
#          actor_1_name  imdb_score
# 0        Martin Short         9.5
# 1      Morgan Freeman         9.3
# 2           Al Pacino         9.2
# 3      Krystyna Janda         9.1
# 4      Krystyna Janda         9.1
# 5        Matthew Ziff         9.1
# 6      Christian Bale         9.0
# 7      Robert De Niro         9.0
# 8       Kirsten Dunst         9.0
# 9       Orlando Bloom         8.9
# 10        Liam Neeson         8.9
# 11       Bruce Willis         8.9
# 12     Clint Eastwood         8.9
# 13        Jack Warden         8.9
# 14  Leonardo DiCaprio         8.8
# 15    Christopher Lee         8.8
# 16       Elden Henson         8.8
# 17          Brad Pitt         8.8
# 18          Tom Hanks         8.8
# 19     Rob McElhenney         8.8
# 20      Harrison Ford         8.8
# 21    Christopher Lee         8.7
# 22       Keanu Reeves         8.7
# 23       Zach Gilford         8.7
# 24     Jackie Gleason         8.7

# %%
movie_df.plot(kind='bar',x='imdb_score',figsize=(15,8), color='bg')

# %%
top_10_m(movie_df, 'movie_title', 'imdb_score')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-188-aa57cce9332a> in <module>()
# ----> 1 top_10_m(movie_df, 'movie_title', 'imdb_score')
#
# <ipython-input-187-1894e9970454> in top_10_m(df, col1, col2)
#       1 def top_10_m(df, col1, col2):
# ----> 2     sortk = df.nlargest(10, 'col2').head(10)[['col1','col2']]
#       3     return sortk
#       4
#       5
#
# C:\Users\arjun\Anaconda3\envs\py27\lib\site-packages\pandas\core\frame.pyc in nlargest(self, n, columns, keep)
#    3439                                        n=n,
#    3440                                        keep=keep,
# -> 3441                                        columns=columns).nlargest()
#    3442
#    3443     def nsmallest(self, n, columns, keep='first'):
#
# C:\Users\arjun\Anaconda3\envs\py27\lib\site-packages\pandas\core\algorithms.pyc in nlargest(self)
#     998
# ...

# %%
def top_10(df, col1, col2):
    sortd = {0}.nlargest(10, '{2}').head(10)[['{1}','{2}']].format(df,col1,col2)
    return sortd

# %%
top_10(movie_df, "movie_title", "imdb_score" )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-20f6811634af> in <module>()
# ----> 1 top_10(movie_df, "movie_title", "imdb_score" )
#
# <ipython-input-10-46111aa7ed1a> in top_10(df, col1, col2)
#       1 def top_10(df, col1, col2):
# ----> 2     sortd = {0}.nlargest(10, '{2}').head(10)[['{1}','{2}']].format(df,col1,col2)
#       3     return sortd
#       4
#       5
#
# AttributeError: 'set' object has no attribute 'nlargest'

# %%
movie_df['movie_title'].groupby(movie_df['imdb_score'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-160-fb7867bd406b> in <module>()
# ----> 1 movie_df['movie_title'].groupby(movie_df['imdb_score']).nlargest(10, 'imdb_score')
#
# C:\Users\arjun\Anaconda3\envs\py27\lib\site-packages\pandas\core\groupby.pyc in nlargest(self, n, keep)
#
# C:\Users\arjun\Anaconda3\envs\py27\lib\site-packages\pandas\core\groupby.pyc in wrapper(*args, **kwargs)
#     612                                                             *args, **kwargs)
#     613                     except (AttributeError):
# --> 614                         raise ValueError
#     615
#     616         return wrapper
#
# ValueError:

# %%
movie_df['imdb_score'].groupby(movie_df['movie_title']).max()
# Out:
# movie_title
# #Horror                                 3.3
# 10 Cloverfield Lane                     7.3
# 10 Days in a Madhouse                   7.5
# 10 Things I Hate About You              7.2
# 10,000 B.C.                             7.2
# 102 Dalmatians                          4.8
# 10th & Wolf                             6.4
# 11:14                                   7.2
# 12 Angry Men                            8.9
# 12 Monkeys                              7.6
# 12 Rounds                               5.6
# 12 Years a Slave                        8.1
# 127 Hours                               7.6
# 13 Going on 30                          6.1
# 13 Hours                                7.4
# 1408                                    6.8
# 15 Minutes                              6.1
# 16 Blocks                               6.6
# 16 to Life                              6.3
# 17 Again                                6.4
# 1776                                    7.6
# ...

# %%
m = movie_df.groupby('movie_title')['imdb_score', 'movie_facebook_likes'].max().sort_values(by = 'imdb_score', ascending = False)
m
# Out:
#                                                     imdb_score  \
# movie_title
# Towering Inferno                                           9.5
# The Shawshank Redemption                                   9.3
# The Godfather                                              9.2
# Dekalog                                                    9.1
# Kickboxer: Vengeance                                       9.1
# The Dark Knight                                            9.0
# The Godfather: Part II                                     9.0
# Fargo                                                      9.0
# The Good, the Bad and the Ugly                             8.9
# Pulp Fiction                                               8.9
# The Lord of the Rings: The Return of the King              8.9
# Schindler's List                                           8.9
# 12 Angry Men                                               8.9
# Forrest Gump                                               8.8
# ...

# %%
m.loc[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-198-d396fa252e7d> in <module>()
# ----> 1 m.loc[0]
#
# C:\Users\arjun\Anaconda3\envs\py27\lib\site-packages\pandas\core\indexing.pyc in __getitem__(self, key)
#    1326         else:
#    1327             key = com._apply_if_callable(key, self.obj)
# -> 1328             return self._getitem_axis(key, axis=0)
#    1329
#    1330     def _is_scalar_access(self, key):
#
# C:\Users\arjun\Anaconda3\envs\py27\lib\site-packages\pandas\core\indexing.pyc in _getitem_axis(self, key, axis)
#    1549
#    1550         # fall thru to straight lookup
# -> 1551         self._has_valid_type(key, axis)
#    1552         return self._get_label(key, axis=axis)
#    1553
#
# C:\Users\arjun\Anaconda3\envs\py27\lib\site-packages\pandas\core\indexing.pyc in _has_valid_type(self, key, axis)
#    1430
#    1431             try:
# ...

# %%
m = movie_df.sort_values(by='movie_facebook_likes', ascending=False).head(20)
m
# Out:
#       color          director_name  num_critic_for_reviews  duration  \
# 96    Color      Christopher Nolan                   712.0     169.0
# 296   Color      Quentin Tarantino                   765.0     165.0
# 10    Color            Zack Snyder                   673.0     183.0
# 128   Color          George Miller                   739.0     120.0
# 179   Color  Alejandro G. Iñárritu                   556.0     156.0
# 97    Color      Christopher Nolan                   642.0     148.0
# 99    Color          Peter Jackson                   645.0     182.0
# 2614  Color          Morten Tyldum                   454.0     114.0
# 3     Color      Christopher Nolan                   813.0     164.0
# 278   Color           Ridley Scott                   568.0     151.0
# 29    Color        Colin Trevorrow                   644.0     124.0
# 1578  Color           Wes Anderson                   536.0      99.0
# 2058  Color            Spike Jonze                   574.0     126.0
# ...

# %%
l = movie_df['imdb_score'].nlargest(25)
l
# Out:
# 2765    9.5
# 1937    9.3
# 3466    9.2
# 2824    9.1
# 3207    9.1
# 4409    9.1
# 66      9.0
# 2837    9.0
# 3481    9.0
# 339     8.9
# 1874    8.9
# 3355    8.9
# 4498    8.9
# 4822    8.9
# 97      8.8
# 270     8.8
# 459     8.8
# 683     8.8
# 836     8.8
# 1842    8.8
# 2051    8.8
# 340     8.7
# 654     8.7
# 1620    8.7
# 1818    8.7
# Name: imdb_score, dtype: float64

# %%
g = df_highest_rate.groupby('imdb_score').apply(lambda x: x.head(2))
h = g.set_index('imdb_score').reset_index()

# %% [markdown]
# #### #Top 25 rated movies

# %%
top_rated = movie_df[movie_df['imdb_score'] >= 8].sort_values(by = 'imdb_score', ascending = False)
top_rated = top_rated.dropna()
top_rated.loc[:,['movie_title',"title_year", 'director_name', 'gross', 'actor_1_name', 'actor_2_name', 'imdb_score']]
# Out:
#                                             movie_title  title_year  \
# 1937                          The Shawshank Redemption       1994.0
# 3466                                     The Godfather       1972.0
# 2837                            The Godfather: Part II       1974.0
# 66                                     The Dark Knight       2008.0
# 3355                                      Pulp Fiction       1994.0
# 339      The Lord of the Rings: The Return of the King       2003.0
# 1874                                  Schindler's List       1993.0
# 4498                    The Good, the Bad and the Ugly       1966.0
# 97                                           Inception       2010.0
# 836                                       Forrest Gump       1994.0
# 683                                         Fight Club       1999.0
# 270   The Lord of the Rings: The Fellowship of the R...      2001.0
# 2051    Star Wars: Episode V - The Empire Strikes Back       1980.0
# ...

# %%
# Example of Classes! 




class Most_rated(object):
    
    def __init__(self, df, col1,col2, year):
        self.df = df
        self.col1 = col1
        self.col2 = col2
        self.year = year
        
    def most_rated(self):
        mr = self.df.groupby([self.col1,self.col2]).max()
        return mr
    
    def most_yr_rated(self):
        myr = self.df.groupby([self.col1,self.col2]).max().loc[self.year]
        return myr

# %%
class Most_rated1(object):
    
    def __init__(self, df):
        self.df = df
        
    def most_rated(self, col1, col2): 
        mr = self.df.groupby([col1,col2]).max()
        return mr
    
    def

# %%
l2 = Most_rated1(movie_df)

# %%
l2.most_rated("title_year","gross").tail(10)
# Out:
#                         color            director_name  \
# title_year gross
# 2016.0     126088877.0  Color  Rawson Marshall Thurber
#            130468626.0  Color               Justin Lin
#            143523463.0  Color       Alessandro Carloni
#            154985087.0  Color             Bryan Singer
#            161087183.0  Color               David Ayer
#            323505540.0  Color            Yarrow Cheney
#            330249062.0  Color              Zack Snyder
#            362645141.0  Color              Jon Favreau
#            363024263.0  Color               Tim Miller
#            407197282.0  Color            Anthony Russo
#
#                         num_critic_for_reviews  duration  \
# title_year gross
# 2016.0     126088877.0                   177.0     107.0
#            130468626.0                   322.0     122.0
#            143523463.0                   210.0      95.0
#            154985087.0                   396.0     144.0
# ...

# %%
l = Most_rated(movie_df,"title_year","imdb_score", 1934)

# %%
l.most_yr_rated()
# Out:
#                        color director_name  num_critic_for_reviews  duration  \
# imdb_score
# 8.2          Black and White   Frank Capra                   124.0      65.0
#
#             director_facebook_likes  actor_3_facebook_likes actor_2_name  \
# imdb_score
# 8.2                           964.0                    21.0    Alan Hale
#
#             actor_1_facebook_likes  gross          genres  \
# imdb_score
# 8.2                          380.0    NaN  Comedy|Romance
#
#                    ...                               plot_keywords  \
# imdb_score         ...
# 8.2                ...           bus|detective|love|money|reporter
#
#                                               movie_imdb_link  \
# imdb_score
# 8.2         http://www.imdb.com/title/tt0025316/?ref_=fn_t...
#
#             num_user_for_reviews  language country  content_rating    budget  \
# imdb_score
# 8.2                        235.0   English     USA         Unrated  325000.0
#
# ...

# %%
most_rated = movie_df.groupby(['title_year','imdb_score']).max()
# most_rated

most_rated.loc[2011]
# Out:
#                        color          director_name  num_critic_for_reviews  \
# imdb_score
# 1.6                    Color             Jon M. Chu                    84.0
# 3.0                      NaN        Brandon Landers                     NaN
# 3.2                    Color           Travis Legge                     5.0
# 3.3                    Color              Tom Brady                    49.0
# 3.4                    Color           Dennis Dugan                   156.0
# 3.6                    Color       Robert Rodriguez                    76.0
# 3.7                    Color           Deryck Broom                     7.0
# 3.9                    Color          Carmen Marron                     8.0
# 4.0                    Color            Jason Trost                   231.0
# 4.3                    Color         Mark Neveldine                   287.0
# 4.4                    Color           Tanner Beard                    91.0
# ...

# %%
dfM = movie_df['title_year'].groupby(movie_df['imdb_score']).max()
dfM
# Out:
# imdb_score
# 1.6    2011.0
# 1.7    2012.0
# 1.9    2008.0
# 2.0    2014.0
# 2.1    2006.0
# 2.2    2015.0
# 2.3    2007.0
# 2.4    2003.0
# 2.5    2008.0
# 2.6    2013.0
# 2.7    2010.0
# 2.8    2015.0
# 2.9    2009.0
# 3.0    2011.0
# 3.1    2015.0
# 3.2    2015.0
# 3.3    2015.0
# 3.4    2016.0
# 3.5    2016.0
# 3.6    2015.0
# 3.7    2016.0
# 3.8    2014.0
# 3.9    2015.0
# 4.0    2016.0
# 4.1    2015.0
# 4.2    2016.0
# 4.3    2015.0
# 4.4    2015.0
# 4.5    2016.0
# 4.6    2015.0
#         ...
# 6.5    2015.0
# 6.6    2016.0
# 6.7    2016.0
# 6.8    2016.0
# 6.9    2016.0
# 7.0    2016.0
# 7.1    2016.0
# 7.2    2016.0
# 7.3    2016.0
# 7.4    2016.0
# 7.5    2016.0
# 7.6    2016.0
# 7.7    2016.0
# 7.8    2016.0
# 7.9    2015.0
# 8.0    2016.0
# 8.1    2016.0
# 8.2    2016.0
# 8.3    2015.0
# 8.4    2015.0
# 8.5    2016.0
# 8.6    2015.0
# 8.7    2016.0
# 8.8    2010.0
# 8.9    2003.0
# 9.0    2008.0
# 9.1    2016.0
# 9.2    1972.0
# 9.3    1994.0
# 9.5       NaN
# ...

# %%
df_gross = movie_df.groupby('director_name')['imdb_score'].sum()

df_gross.sort_values(ascending=False).head(20)
# Out:
# director_name
# Steven Spielberg        194.5
# Woody Allen             154.2
# Martin Scorsese         153.2
# Clint Eastwood          144.5
# Ridley Scott            120.2
# Tim Burton              110.9
# Steven Soderbergh       107.3
# Spike Lee               105.1
# Oliver Stone             97.3
# Robert Zemeckis          95.0
# Peter Jackson            92.1
# Ron Howard               90.1
# John Carpenter           89.9
# Sam Raimi                89.8
# Michael Bay              86.3
# Renny Harlin             86.2
# Barry Levinson           85.5
# Joel Schumacher          83.3
# Richard Donner           81.9
# Francis Ford Coppola     81.6
# Name: imdb_score, dtype: float64

# %%
df_gross_actor1 = movie_df.groupby('actor_1_name')['gross'].sum()
df_gross_actor1.sort_values(ascending=False).head(10)
# Out:
# actor_1_name
# Johnny Depp          3.719618e+09
# Harrison Ford        3.391556e+09
# Tom Hanks            3.264559e+09
# Tom Cruise           2.987622e+09
# J.K. Simmons         2.856407e+09
# Will Smith           2.762618e+09
# Chris Hemsworth      2.729133e+09
# Leonardo DiCaprio    2.640582e+09
# Robert Downey Jr.    2.456990e+09
# Jennifer Lawrence    2.367856e+09
# Name: gross, dtype: float64

# %%
df_top_grossing_actors = movie_df.groupby('actor_1_name')['budget'].sum()
df_top_grossing_actors.sort_values(ascending=False).head(10)
# Out:
# actor_1_name
# Doona Bae           1.221550e+10
# Min-sik Choi        4.215800e+09
# Johnny Depp         3.141600e+09
# Marcell Nagy        2.500000e+09
# Minnie Driver       2.491000e+09
# William Hootkins    2.127520e+09
# Will Smith          2.036100e+09
# Hugh Jackman        1.913000e+09
# J.K. Simmons        1.907300e+09
# Tom Cruise          1.838800e+09
# Name: budget, dtype: float64

# %%
df_top_grossing_directors_gross = movie_df.groupby('director_name')['gross'].sum()
z =df_top_grossing_directors_gross.sort_values(ascending=False).head(10)

# %%
df_top_grossing_directors = movie_df.groupby('director_name')['budget'].sum()
b = df_top_grossing_directors.sort_values(ascending=False).head(10)

# %%
z.tolist()
# Out:
# [4114233101.0,
#  2592969279.0,
#  2231242537.0,
#  2071275480.0,
#  2049549198.0,
#  1948125910.0,
#  1813227576.0,
#  1741418480.0,
#  1730886628.0,
#  1619309108.0]

# %%
if x in z == y in b :
    print(x)

# %%
top_imdb = movie_df.sort_values('imdb_score', ascending = False)
# language', 'country', 'budget',, 'duration'
topi = top_imdb.loc[:,['movie_title', 'imdb_score','title_year','language',  'director_name', 'gross' ]]
topi.head(20)
# Out:
#                                             movie_title  imdb_score  \
# 2765                      Towering Inferno                      9.5
# 1937                          The Shawshank Redemption          9.3
# 3466                                     The Godfather          9.2
# 4409                              Kickboxer: Vengeance          9.1
# 2824                               Dekalog                      9.1
# 3207                               Dekalog                      9.1
# 66                                     The Dark Knight          9.0
# 2837                            The Godfather: Part II          9.0
# 3481                                 Fargo                      9.0
# 339      The Lord of the Rings: The Return of the King          8.9
# 4822                                      12 Angry Men          8.9
# 4498                    The Good, the Bad and the Ugly          8.9
# 3355                                      Pulp Fiction          8.9
# ...

# %%
#indian top 10 rated movies
ind = topi[topi['language']== 'Hindi']
ind.head(10)
# Out:
#                               movie_title  imdb_score  title_year language  \
# 3870                             Airlift          8.5      2016.0    Hindi
# 3685                     Rang De Basanti          8.4      2006.0    Hindi
# 4160                Lage Raho Munna Bhai          8.2      2006.0    Hindi
# 3344                     My Name Is Khan          8.0      2010.0    Hindi
# 3510                          Veer-Zaara          7.9      2004.0    Hindi
# 4088                               Water          7.8      2005.0    Hindi
# 1056                               Earth          7.8      1998.0    Hindi
# 4385                        The Lunchbox          7.8      2013.0    Hindi
# 4528  Rocket Singh: Salesman of the Year          7.5      2009.0    Hindi
# 3789                   Gandhi, My Father          7.4      2007.0    Hindi
#
#                 director_name      gross
# 3870               Raja Menon        NaN
# 3685  Rakeysh Omprakash Mehra  2197331.0
# ...

# %%
# score_by_cntry = movie_df.groupby('country',as_index=False).mean().sort_values(by='imdb_score', ascending=False)
# score_by_cntry

count_by_cntry = movie_df.groupby('country',
                                         as_index=True).count().sort_values(by='gross',
                                                                             ascending=False)

count_by_cntry.head(5)
# Out:
#          color  director_name  num_critic_for_reviews  duration  \
# country
# USA       3793           3733                    3768      3801
# UK         447            434                     446       445
# France     154            152                     154       154
# Germany     97             97                      97        97
# Canada     126            123                     125       126
#
#          director_facebook_likes  actor_3_facebook_likes  actor_2_name  \
# country
# USA                         3733                    3794          3800
# UK                           434                     447           448
# France                       152                     153           154
# Germany                       97                      97            97
# Canada                       123                     125           125
#
#          actor_1_facebook_likes  gross  genres          ...           \
# country                                                 ...
# ...

# %%
df_movies_year = movie_df.groupby(['title_year','movie_title']).max()
df_movies_year.head(25)
# Out:
#                                                                          color  \
# title_year movie_title
# 1916.0     Intolerance: Love's Struggle Throughout the Ages    Black and White
# 1920.0     Over the Hill to the Poorhouse                      Black and White
# 1925.0     The Big Parade                                      Black and White
# 1927.0     Metropolis                                          Black and White
# 1929.0     Pandora's Box                                       Black and White
#            The Broadway Melody                                 Black and White
# 1930.0     Hell's Angels                                       Black and White
# 1932.0     A Farewell to Arms                                  Black and White
# 1933.0     42nd Street                                         Black and White
#            She Done Him Wrong                                  Black and White
# 1934.0     It Happened One Night                               Black and White
# ...

# %%
f =movie_df.budget.groupby(movie_df.country).mean().sort_values(ascending = False)
f
# Out:
# country
# South Korea             1.383960e+09
# Hungary                 1.260000e+09
# Japan                   3.505960e+08
# Thailand                2.272500e+08
# India                   9.797336e+07
# New Line                9.000000e+07
# New Zealand             8.152692e+07
# China                   6.221900e+07
# Czech Republic          4.881667e+07
# Peru                    4.500000e+07
# Spain                   4.281667e+07
# USA                     3.575599e+07
# Aruba                   3.500000e+07
# Libya                   3.500000e+07
# Germany                 3.338900e+07
# Australia               3.117211e+07
# France                  3.067203e+07
# UK                      2.766607e+07
# Chile                   2.600000e+07
# Hong Kong               2.487333e+07
# Belgium                 2.450000e+07
# Norway                  2.088750e+07
# West Germany            2.050000e+07
# Panama                  2.000000e+07
# Georgia                 2.000000e+07
# ...

# %%
dm = movie_df['imdb_score'].groupby(movie_df['title_year']).max()
dm
# Out:
# title_year
# 1916.0    8.0
# 1920.0    4.8
# 1925.0    8.3
# 1927.0    8.3
# 1929.0    8.0
# 1930.0    7.8
# 1932.0    6.6
# 1933.0    7.7
# 1934.0    8.2
# 1935.0    7.8
# 1936.0    8.6
# 1937.0    7.8
# 1938.0    8.0
# 1939.0    8.2
# 1940.0    8.2
# 1941.0    7.8
# 1942.0    8.6
# 1943.0    7.0
# 1944.0    6.5
# 1945.0    8.0
# 1946.0    8.6
# 1947.0    7.7
# 1948.0    7.8
# 1949.0    7.4
# 1950.0    7.0
# 1951.0    8.0
# 1952.0    8.3
# 1953.0    7.8
# 1954.0    8.7
# 1955.0    8.1
#          ...
# 1987.0    8.1
# 1988.0    8.2
# 1989.0    8.3
# 1990.0    8.7
# 1991.0    8.6
# 1992.0    8.4
# 1993.0    8.9
# 1994.0    9.3
# 1995.0    8.6
# 1996.0    8.2
# 1997.0    8.5
# 1998.0    8.6
# 1999.0    8.8
# 2000.0    8.5
# 2001.0    8.8
# 2002.0    8.7
# 2003.0    8.9
# 2004.0    8.3
# 2005.0    8.3
# 2006.0    8.5
# 2007.0    8.4
# 2008.0    9.0
# 2009.0    8.3
# 2010.0    8.8
# 2011.0    8.5
# 2012.0    8.5
# 2013.0    8.4
# 2014.0    8.7
# 2015.0    8.6
# 2016.0    9.1
# ...

# %%
# Out:
# 6.7    223
# 6.6    201
# 7.2    195
# 6.5    186
# 6.4    185
# 7.3    184
# 7.0    184
# 7.1    181
# 6.8    181
# 6.1    179
# 6.3    176
# 6.2    175
# 6.9    174
# 7.4    147
# 5.9    144
# 7.5    140
# 6.0    131
# 7.6    124
# 5.8    124
# 5.7    117
# 7.7    114
# 5.6    112
# 7.8    106
# 5.4    104
# 5.5     98
# 5.3     92
# 8.0     75
# 7.9     75
# 5.1     71
# 8.1     69
#       ...
# 3.5     15
# 3.9     14
# 3.8     14
# 3.6     14
# 8.7     13
# 3.4     12
# 2.8      9
# 3.7      9
# 3.1      8
# 8.8      7
# 3.2      7
# 2.7      6
# 3.0      5
# 8.9      5
# 2.9      4
# 2.2      3
# 2.1      3
# 1.9      3
# 9.0      3
# 9.1      3
# 2.3      3
# 2.5      2
# 2.0      2
# 2.4      2
# 2.6      2
# 9.3      1
# 1.7      1
# 9.5      1
# 9.2      1
# 1.6      1
# Name: imdb_score, Length: 78, dtype: int64

# %% [markdown]
# #####"""each year best movies based on higest rated
#
# best movie higest budget- for each year
#
# each year - top 5 rated
# to 5 actors, directors
#
# no, of mvs, ratings, fb likes
#
# each year mean avg for quality of movies
#
# which year had best avg ratings ."""

# %%
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
# color                        5024 non-null object
# director_name                4939 non-null object
# num_critic_for_reviews       4993 non-null float64
# duration                     5028 non-null float64
# director_facebook_likes      4939 non-null float64
# actor_3_facebook_likes       5020 non-null float64
# actor_2_name                 5030 non-null object
# actor_1_facebook_likes       5036 non-null float64
# gross                        4159 non-null float64
# genres                       5043 non-null object
# actor_1_name                 5036 non-null object
# movie_title                  5043 non-null object
# num_voted_users              5043 non-null int64
# cast_total_facebook_likes    5043 non-null int64
# actor_3_name                 5020 non-null object
# facenumber_in_poster         5030 non-null float64
# ...

# %%
f = movie_df['budget'].sum()
g = movie_df['gross'].sum()

k = f/g
k
# Out:
# 0.8974803039079551

# %%
# Top actor by imdb score
actr_score = movie_df['imdb_score'].groupby(movie_df['actor_1_name']).sum()
actr_score = actr_score.to_frame(name= 'imdb_score')

# %%
actr_score
# Out:
#                        imdb_score
# actor_1_name
# 50 Cent                       5.0
# A.J. Buckley                  6.8
# Aaliyah                       5.2
# Aasif Mandvi                  6.7
# Abbie Cornish                21.2
# Abhishek Bachchan             9.5
# Abigail Evans                 8.7
# Abigail Spencer               5.3
# Adam Arkin                   13.0
# Adam Baldwin                 28.9
# Adam Garcia                  13.5
# Adam Goldberg                33.1
# Adam LeFevre                  7.2
# Adam Sandler                 89.3
# Adam Scott                   50.1
# Adrian Martinez               5.9
# Adriana Barraza               8.1
# Adriana Caselotti             7.7
# Agnes Moorehead               7.0
# Ahna O'Reilly                 7.5
# Aidan Quinn                  31.7
# Aidan Turner                 29.3
# Aimee Garcia                 10.6
# Aisha Tyler                   6.8
# Akon                          5.6
# Aksel Hennie                  7.6
# ...

# %%
(actr_score.sort_values('imdb_score', ascending = False)).head(10)
# Out:
#                    imdb_score
# actor_1_name
# Robert De Niro          330.6
# Johnny Depp             276.2
# Denzel Washington       212.5
# Matt Damon              209.5
# J.K. Simmons            206.9
# Nicolas Cage            201.9
# Bruce Willis            197.3
# Harrison Ford           193.3
# Liam Neeson             187.7
# Tom Hanks               178.2

# %%
movie_df[['movie_title','title_year']]
# Out:
#                                             movie_title  title_year
# 0                                               Avatar       2009.0
# 1             Pirates of the Caribbean: At World's End       2007.0
# 2                                              Spectre       2015.0
# 3                                The Dark Knight Rises       2012.0
# 4     Star Wars: Episode VII - The Force Awakens    ...         NaN
# 5                                          John Carter       2012.0
# 6                                         Spider-Man 3       2007.0
# 7                                              Tangled       2010.0
# 8                              Avengers: Age of Ultron       2015.0
# 9               Harry Potter and the Half-Blood Prince       2009.0
# 10                  Batman v Superman: Dawn of Justice       2016.0
# 11                                    Superman Returns       2006.0
# 12                                   Quantum of Solace       2008.0
# ...

# %%
for movie in

# %%
# df = movie_df
def topmy(df):
   

    return y

# %%
from itertools import groupby

# %%
# y = list([x for x in movie_df['imdb_score'] if x >= 9])
# y

for x in movie_df['imdb_score']:
    for y in  movie_df['title_year']:
        for z in movie_df['movie_title']:
            if x >=8.5:
#                 print (movie_df.groupby([x,y,z].size().sort_values(ascending=False)[:25]))
#                 print (x,y,z)
#                 print( x, z in groupby(y))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-70-05b8e03962dc> in <module>()
#       6         for z in movie_df['movie_title']:
#       7             if x >=8.5:
# ----> 8                 print (movie_df.groupby([x,y,z].size().sort_values(ascending=False)[:25]))
#       9 #                 print (x,y,z)
#      10 #                 print( x, z in groupby(y))
#
# AttributeError: 'list' object has no attribute 'size'

# %%
for every year if score is > 9 print year, name

# %%
for evry year print the highest value of score

# %%
for x in movie_df['title_year']:
       for y in movie_df['imdb_score']:
#         if y == int(max(list(y))):
#                   print (x,y)
    print (max(int(y) for y in movie_df['imdb_score'])
# Out:
#   File "<ipython-input-113-d9baecd0d6af>", line 3
#
#     ^
# SyntaxError: invalid syntax

# %%
import numpy as np

# %%
for x in movie_df['title_year']:
    for y in movie_df['imdb_score']:
        if y >= 9:
#             print (x,size(y))
            print (x,y)
# Out:
# (2009.0, 9.0)
# (2009.0, 9.3000000000000007)
# (2009.0, 9.5)
# (2009.0, 9.0999999999999996)
# (2009.0, 9.0)
# (2009.0, 9.0999999999999996)
# (2009.0, 9.1999999999999993)
# (2009.0, 9.0)
# (2009.0, 9.0999999999999996)
# (2007.0, 9.0)
# (2007.0, 9.3000000000000007)
# (2007.0, 9.5)
# (2007.0, 9.0999999999999996)
# (2007.0, 9.0)
# (2007.0, 9.0999999999999996)
# (2007.0, 9.1999999999999993)
# (2007.0, 9.0)
# (2007.0, 9.0999999999999996)
# (2015.0, 9.0)
# (2015.0, 9.3000000000000007)
# (2015.0, 9.5)
# (2015.0, 9.0999999999999996)
# (2015.0, 9.0)
# (2015.0, 9.0999999999999996)
# (2015.0, 9.1999999999999993)
# (2015.0, 9.0)
# (2015.0, 9.0999999999999996)
# (2012.0, 9.0)
# (2012.0, 9.3000000000000007)
# (2012.0, 9.5)
# (2012.0, 9.0999999999999996)
# (2012.0, 9.0)
# (2012.0, 9.0999999999999996)
# (2012.0, 9.1999999999999993)
# (2012.0, 9.0)
# (2012.0, 9.0999999999999996)
# (nan, 9.0)
# (nan, 9.3000000000000007)
# (nan, 9.5)
# (nan, 9.0999999999999996)
# (nan, 9.0)
# (nan, 9.0999999999999996)
# ...

# %%
p = movie_df.groupby(['title_year','imdb_score']).size().sort_values(ascending=False)[:25]
p
# Out:
# title_year  imdb_score
# 2010.0      6.3           19
#             6.4           17
# 2013.0      6.7           17
# 2010.0      6.5           15
# 2002.0      6.7           15
# 2005.0      6.6           14
# 2009.0      6.2           14
# 2008.0      6.7           14
#             6.1           14
# 2013.0      6.5           14
# 2006.0      6.6           13
# 2007.0      5.9           13
# 2005.0      6.9           13
# 2009.0      7.2           13
# 2014.0      6.8           13
# 2006.0      5.6           13
#             7.3           13
# 2008.0      6.5           13
# 2009.0      7.3           12
#             7.4           12
# 2012.0      5.7           12
# 2009.0      6.7           12
# 2011.0      7.1           12
# 2002.0      7.2           12
# 2007.0      6.3           12
# dtype: int64
